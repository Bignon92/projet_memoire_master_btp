# %% [markdown]
# # Objectif
#
# Segmenter les engins et risques.
#
# **Pertinence dans le mémoire**
#
# Permet d’identifier des profils de risque similaires.

# %% [markdown]
# ## 2. Standardisation

# %% [markdown]
# ## 3. KMeans

# %% [markdown]
# ## 4. Détermination du nombre optimal clusters
#
# - méthode du coude.

# %% [markdown]
# ## 5. Visualisation clusters
