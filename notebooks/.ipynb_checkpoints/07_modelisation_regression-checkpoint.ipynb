# %% [markdown]
# # Objectif
#
# Prédire le coût futur des sinistres.
#
#
# **Pertinence dans le mémoire**
#
# Cette partie répond directement à l’objectif d’optimisation financière.

# %% [markdown]
# ## 1. Variables explicatives

# %%
## 2. Modèles

- Linear Regression ;
- RandomForestRegressor ;
- XGBoost Regressor.

# %%
## 3. Entraînement

# %%
## 4. Évaluation

- RMSE ;
- MAE ;
- R².
