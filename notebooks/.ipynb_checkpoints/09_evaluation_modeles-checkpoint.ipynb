# %% [markdown]
# # Objectif
#
# Comparer les performances des modèles.
#
#
# **Pertinence dans le mémoire**
#
# Permet de justifier scientifiquement le choix du meilleur modèle.

# %% [markdown]
# ## Classification
#
# - Accuracy ;
# - Precision ;
# - Recall ;
# - F1-score ;
# - ROC AUC.

# %% [markdown]
# ## Régression
#
# - RMSE ;
# - MAE ;
# - R².

# %% [markdown]
# ## Comparaison visuelle
#
# - tableaux ;
# - graphiques.
