# %% [markdown]
# # Objectif
#
# Préparer les datasets pour Power BI.
#
# ---
#
# # Pertinence dans le mémoire
#
# Power BI représente la couche décisionnelle finale du système.

# %% [markdown]
# ## 1. Extraction des vues analytiques

# %% [markdown]
# ## 2. Export CSV

# %% [markdown]
# ## 3. Export résultats ML

# %% [markdown]
# ## 4. Préparation KPIs
