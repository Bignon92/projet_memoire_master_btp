# %% [markdown]
# # Objectif
#
# Construire le Data Warehouse dans PostgreSQL.
# **Pertinence dans le mémoire**
#
# Cette étape matérialise :
# - le système décisionnel ;
# - l’architecture BI ;
# - le modèle multidimensionnel.

# %% [markdown]
# ## 1. Connexion PostgreSQL
#
# - SQLAlchemy ;
# - psycopg2.

# %%
# IMPORTATION DES LIBRAIRIES
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy import text

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)

print("Librairies chargées")
# Out:
# Librairies chargées

# %%
# PARAMÈTRES DE CONNEXION
USER = "postgres"

PASSWORD = "keren"

HOST = "localhost"

PORT = "5432"

DATABASE = "btp_sinistres_dwh"

# %%
# CONNEXION POSTGRESQL
engine = create_engine(

    f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"

)

print("Connexion PostgreSQL réussie")
# Out:
# Connexion PostgreSQL réussie

# %%
# TEST CONNEXION
with engine.connect() as conn:

    result = conn.execute(
        text("SELECT version();")
    )

    for row in result:
        print(row)
# Out:
# ('PostgreSQL 18.4 on x86_64-windows, compiled by msvc-19.44.35226, 64-bit',)

# %%
# CHARGEMENT DES DONNÉES
dataset = pd.read_csv(
    "../data/processed/dataset_analytique.csv"
)

trc = pd.read_csv(
    "../data/processed/sinistre_trc_enrichi.csv"
)

print("Datasets chargés")
# Out:
# Datasets chargés

# %%
# APERÇU DES DONNÉES
display(dataset.head())

display(dataset.shape)
# Out:
#      id_sinistre  annee  mois date_accident immatriculation  \
# 0  AUTO-2022-001   2022     7    2022-07-17     PRT-0108-BJ
# 1  AUTO-2022-002   2022     3    2022-03-02     PRT-0068-BJ
# 2  AUTO-2022-003   2022     9    2022-09-15     PRT-0318-BJ
# 3  AUTO-2022-004   2022     8    2022-08-27     PRT-0586-BJ
# 4  AUTO-2022-005   2022     9    2022-09-27     PRT-0395-BJ
#
#      type_engin_sinistre marque_sinistre  age_vehicule_ans_sinistre  \
# 0              NIVELEUSE        LIEBHERR                         13
# 1              BULLDOZER        LIEBHERR                         10
# 2           CAMION BENNE             MAN                          9
# 3              NIVELEUSE        VOLVO CE                          4
# 4  CAMION MALAXEUR BÉTON             DAF                          2
#
#   etat_vehicule departement_accident             axe_routier  \
# 0       MAUVAIS                OUÉMÉ    RN6 NATITINGOU-KÉROU
# 1       MAUVAIS              ALIBORI  VOIRIE URBAINE PARAKOU
# 2       MAUVAIS           ATLANTIQUE      RN7 COTONOU-OUIDAH
# 3           BON               BORGOU  VOIRIE URBAINE PARAKOU
# 4           BON                OUÉMÉ            PISTE RURALE
#
#         type_accident           responsabilite         gravite tiers_implique  \
# 0  COLLISION FRONTALE              RESPONSABLE  MATÉRIEL GRAVE            OUI
# 1        RENVERSEMENT              RESPONSABLE  MATÉRIEL LÉGER            OUI
# 2   ACCROCHAGE MINEUR  RESPONSABILITÉ PARTAGÉE  MATÉRIEL LÉGER            OUI
# 3   ACCROCHAGE MINEUR              RESPONSABLE  MATÉRIEL GRAVE            NON
# 4     SORTIE DE ROUTE  RESPONSABILITÉ PARTAGÉE  MATÉRIEL LÉGER            NON
#
#   assureur_sinistre  montant_declare_fcfa  franchise_fcfa  \
# 0            COLINA               1745000          339000
# 1        SAAR-BÉNIN                242000          114000
# 2            COLINA                471000          270000
# 3        NSIA BÉNIN               6000000          321000
# 4            COLINA                500000          243000
#
#    montant_indemnise_fcfa  delai_declaration_jours  delai_reglement_jours  \
# 0               1101000.0                        7                  119.0
# 1                     0.0                        5                    0.0
# 2                     0.0                        5                    0.0
# 3               4851000.0                        2                   44.0
# 4                210000.0                        9                   87.0
#
#   statut_dossier  conducteur_anciennete_ans type_sinistre  \
# 0          RÉGLÉ                         17          AUTO
# 1       EN COURS                         19          AUTO
# 2   EN EXPERTISE                         10          AUTO
# 3          RÉGLÉ                          5          AUTO
# 4          RÉGLÉ                         17          AUTO
#
#          type_engin_parc marque_parc  annee_mise_en_service  \
# 0              NIVELEUSE    LIEBHERR                   2011
# 1              BULLDOZER    LIEBHERR                   2014
# 2           CAMION BENNE         MAN                   2015
# 3              NIVELEUSE    VOLVO CE                   2020
# 4  CAMION MALAXEUR BÉTON         DAF                   2022
#
#    age_vehicule_ans_parc departement_affectation  km_parcourus_estimes  \
# 0                     13              ATLANTIQUE                504000
# 1                     10                   OUÉMÉ                250000
# 2                      9              ATLANTIQUE                295000
# 3                      4              ATLANTIQUE                148000
# 4                      2                LITTORAL                 80000
#
#   etat_general assureur_parc  cout_total_fcfa classe_age niveau_experience  \
# 0      MAUVAIS        COLINA        1440000.0     ANCIEN       EXPERIMENTE
# 1      MAUVAIS    SAAR-BÉNIN         114000.0     ANCIEN       EXPERIMENTE
# 2      MAUVAIS        COLINA         270000.0     ANCIEN       EXPERIMENTE
# 3          BON    NSIA BÉNIN        5172000.0      MOYEN     INTERMEDIAIRE
# 4          BON        COLINA         453000.0     RECENT       EXPERIMENTE
#
#    score_delai niveau_risque  sinistre_grave  frequence_sinistre  \
# 0        126.0         MOYEN               0                   1
# 1          5.0        FAIBLE               0                   1
# 2          5.0        FAIBLE               0                   2
# 3         46.0         ELEVE               0                   3
# 4         96.0        FAIBLE               0                   2
#
#    score_risque tranche_cout  annee_accident  mois_accident jour_semaine  \
# 0         93.46        MOYEN            2022              7       Sunday
# 1         10.46       FAIBLE            2022              3    Wednesday
# 2         11.76       FAIBLE            2022              9     Thursday
# 3         34.64        ELEVE            2022              8     Saturday
# 4         62.09       FAIBLE            2022              9      Tuesday
#
#    est_weekend categorie_km
# 0         True        ELEVE
# 1        False        ELEVE
# 2        False        ELEVE
# 3         True        MOYEN
# 4        False        MOYEN
# (410, 46)

# %%
# TRUNCATE TABLE FACT
with engine.begin() as conn:

    conn.execute(
        text("""
            TRUNCATE TABLE fact_sinistres CASCADE;
        """)
    )

print("fact_sinistres vidée")
# Out:
# fact_sinistres vidée

# %%
# CHARGEMENT DIM_DATE EXISTANTE
dim_date_sql = pd.read_sql(

    "SELECT * FROM dim_date",

    engine

)

display(dim_date_sql.head())
# Out:
# Empty DataFrame
# Columns: [date_key, date_complete, jour, mois, trimestre, semestre, annee, nom_mois, nom_jour, jour_semaine_num, est_weekend, semaine_annee, est_jour_ferie, est_fin_mois]
# Index: []

# %% [markdown]
# ## 2. Création des dimensions
#
# - dim_date ;
# - dim_vehicule ;
# - dim_conducteur ;
# - dim_chantier ;
# - dim_assureur ;
# - dim_localisation ;
# - dim_type_sinistre.

# %%
# CRÉATION DIM_DATE TEMPORAIRE
dim_date = pd.DataFrame()

dim_date["date_complete"] = pd.to_datetime(
    dataset["date_accident"]
)

dim_date["jour"] = dim_date[
    "date_complete"
].dt.day

dim_date["mois"] = dim_date[
    "date_complete"
].dt.month

dim_date["trimestre"] = dim_date[
    "date_complete"
].dt.quarter

dim_date["semestre"] = np.where(

    dim_date["mois"] <= 6,

    1,

    2

)

dim_date["annee"] = dim_date[
    "date_complete"
].dt.year

dim_date["nom_mois"] = dim_date[
    "date_complete"
].dt.month_name()

dim_date["nom_jour"] = dim_date[
    "date_complete"
].dt.day_name()

dim_date["jour_semaine_num"] = dim_date[
    "date_complete"
].dt.weekday

dim_date["est_weekend"] = dim_date[
    "jour_semaine_num"
].isin([5,6])

dim_date = dim_date.drop_duplicates()

# %% [markdown]
# ## 3. Création de fact_sinistres

# %% [markdown]
# ## 4. Création de fact_predictions

# %% [markdown]
# ## 5. Injection des données
#
# - to_sql ;
# - insertions.
