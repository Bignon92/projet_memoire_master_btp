# %% [markdown]
# # Objectif
#
# Enregistrer les résultats IA dans PostgreSQL.
#
# **Pertinence dans le mémoire**
#
# Cette étape relie le Machine Learning au système décisionnel.

# %% [markdown]
# ## 1. Construction dataframe predictions

# %% [markdown]
# ## 2. Connexion PostgreSQL

# %% [markdown]
# ## 3. Injection dans fact_predictions
