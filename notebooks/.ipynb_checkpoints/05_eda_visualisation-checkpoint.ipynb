# %% [markdown]
# # Objectif
#
# Analyser les données avant modélisation.
# **Pertinence dans le mémoire**
#
# L’EDA permet :
# - d’identifier tendances ;
# - corrélations ;
# - comportements ;
# - facteurs de risque.

# %% [markdown]
# ## 1. Analyse temporelle
#
# - sinistres par mois ;
# - évolution annuelle.

# %% [markdown]
# ## 2. Analyse géographique
#
# - départements ;
# - axes routiers.

# %% [markdown]
# ## 3. Analyse véhicules
#
# - coût par type engin ;
# - âge vs coût.

# %% [markdown]
# ## 4. Heatmaps de corrélation

# %% [markdown]
# ## 5. Boxplots
#
# - coût par gravité ;
# - coût par chantier.
