# %% [markdown]
#  # Objectif
#
# Prédire le niveau de gravité ou le risque.
# **Pertinence dans le mémoire**
#
# Ce notebook constitue le cœur du volet intelligence artificielle.

# %% [markdown]
# # Contenu du notebook
#
# ## 1. Préparation des variables
#
# - X ;
# - y.

# %% [markdown]
# ## 2. Encodage
#
# - LabelEncoder ;
# - OneHotEncoder.

# %% [markdown]
# ## 3. Split train/test

# %% [markdown]
# ## 4. Modèles utilisés
#
# - Logistic Regression ;
# - Random Forest ;
# - XGBoost.

# %% [markdown]
# ## 5. Entraînement

# %% [markdown]
# ## 6. Prédictions
