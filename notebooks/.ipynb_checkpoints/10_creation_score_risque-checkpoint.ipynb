# %% [markdown]
# # Objectif
#
# Créer un score de risque métier.
#
#
# **Pertinence dans le mémoire**
#
# Le score risque constitue le principal outil d’aide à la décision.

# %% [markdown]
# # 1. Définition logique métier

# %% [markdown]
# ## 2. Pondération des variables
#
# - âge ;
# - gravité ;
# - fréquence ;
# - coût.

# %% [markdown]
# ## 3. Calcul score final

# %% [markdown]
# ## 4. Classification
#
# - faible ;
# - moyen ;
# - élevé.
